# %% [markdown]
# ## Source: National Foodprint Accounts
# https://www.kaggle.com/footprintnetwork/national-footprint-accounts-2018
#
# Data from 1992 - 2014

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# !ls ../data
# Out:
#  GlobalLandTemperaturesByCountry.csv
#  GlobalTemperatures.csv
#  health-nutrition-and-population-statistics.csv
#  health-nutrition-and-population-statistics.zip
# 'NFA 2018.csv'

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import clear_output

# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import time
import warnings
warnings.filterwarnings('ignore')

footprint_accounts = pd.read_csv('../data/NFA 2018.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
len(footprint_accounts)
# Out:
# 87020

# %%
footprint_accounts_nonans = footprint_accounts.dropna()
len(footprint_accounts_nonans)
# Out:
# 54330

# %%
list(footprint_accounts)
# Out:
# ['country',
#  'ISO alpha-3 code',
#  'UN_region',
#  'UN_subregion',
#  'year',
#  'record',
#  'crop_land',
#  'grazing_land',
#  'forest_land',
#  'fishing_ground',
#  'built_up_land',
#  'carbon',
#  'total',
#  'Percapita GDP (2010 USD)',
#  'population']

# %%
pd.set_option('display.float_format', lambda x: "{0:,.0f}".format(x))

# %%
a = footprint_accounts.groupby(['country'], as_index=False).agg({'carbon': 'sum'}).sort_values(by=['carbon'], ascending=False)
b = a.reset_index(drop=True)
b
# Out:
#                                     country          carbon
# 0                                     World 819,011,363,331
# 1                  United States of America 204,434,379,220
# 2                                     China 136,907,649,923
# 3                                     Japan  48,196,561,474
# 4                                   Germany  47,075,926,668
# 5                            United Kingdom  28,945,157,161
# 6                        Russian Federation  27,786,518,460
# 7                                     India  27,073,621,325
# 8                                    France  23,719,557,803
# 9                                    Canada  21,519,703,849
# 10                                    Italy  21,386,185,806
# 11                       Korea, Republic of  14,874,749,722
# 12                                   Poland  14,730,227,458
# 13                                   Mexico  14,570,826,757
# 14                              Netherlands  12,613,584,987
# ...

# %%
top_carbon_emitting_countries = list(b['country'][1:20])
top_carbon_emitting_values    = list(b['carbon'][1:20])

# %%
# libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
 
# If you have 2 lists
f, ax = plt.subplots(figsize=(20, 15))
squarify.plot(sizes=top_carbon_emitting_values, label = top_carbon_emitting_countries, alpha=.7 )

plt.axis('off')
plt.show()
 
# If you have a data frame?
# import pandas as pd

# squarify.plot(sizes=b['carbon'], label=b['country'], alpha=.8 )
# plt.axis('off')
# plt.show()
